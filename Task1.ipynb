# %% [markdown]
# <a href="https://colab.research.google.com/github/Pradeepkalai/Intern_project/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
n=input("Enter a Para:")
normalized_text=n.lower()
tokens=normalized_text.split()
stop_word=set(stopwords.words('english'))
filter=[word for word in tokens if word.isalnum() and word not in stop_word]
print("\nNormalised Text:")
print(normalized_text)
print("\nTokens:")
print(tokens)
print("\nRemove stop words:")
print(filter)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Enter a Para:THEre was an Incident accquired by Them.
#
# Normalised Text:
# there was an incident accquired by them.
#
# Tokens:
# ['there', 'was', 'an', 'incident', 'accquired', 'by', 'them.']
#
# Remove stop words:
# ['incident', 'accquired']

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_lab')
text=input("Enter a Para:")
normalized_text=text.lower()
tokens=word_tokenize(normalized_text)
stop_word=set(stopwords.words('english'))
filter=[word for word in tokens if word.isalnum() and word not in stop_word]
print("\nNormalised Text:")
print(normalized_text)
print("\nTokens:")
print(tokens)
print("\nRemove stop words:")
print(filter)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Error loading punkt_lab: Package 'punkt_lab' not found in
# [nltk_data]     index
# Enter a Para:there was THE CAR,BREAKDOWN ON THE BRIDGE..
#
# Normalised Text:
# there was the car,breakdown on the bridge..
#
# Tokens:
# ['there', 'was', 'the', 'car', ',', 'breakdown', 'on', 'the', 'bridge', '..']
#
# Remove stop words:
# ['car', 'breakdown', 'bridge']
